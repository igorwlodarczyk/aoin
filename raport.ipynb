# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %% [markdown]
# # Inicjalizacja losowa

# %%
random_trees = mpimg.imread("data/random.png")
plt.imshow(random_trees)
plt.axis("off")
plt.show()

# %% [markdown]
# # Inicjalizacja greedy

# %%
parent1 = mpimg.imread("data/parent1.png")
plt.imshow(parent1)
plt.axis("off")
plt.show()

# %% [markdown]
# # Algorytm genetyczny

# %% [markdown]
# # crossover

# %%
parent2 = mpimg.imread("data/parent2.png")
child = mpimg.imread("data/child.png")
fig, ax = plt.subplots(1, 3, figsize=(12, 6))
ax[0].imshow(parent1)
ax[0].set_title('parent1')
ax[1].imshow(parent2)
ax[1].set_title('parent2')
ax[2].imshow(child)
ax[2].set_title('child')
# Out:
# Text(0.5, 1.0, 'child')

# %% [markdown]
# ## Wyniki

# %%
from northpole_packing.notebook import plot_ga
plot_ga("data/ga_popsize50.log", "pop_size=50")
plot_ga("data/ga_popsize75.log", "pop_size=75")

# %% [markdown]
# # Symulowane wyżarzanie
# - alpha=0.99986
# - start_temp=1000
# - min_t=1e-6

# %%
from northpole_packing.notebook import plot_sa
plot_sa("data/output_saa_77b06160110c44d9a202bc3bd4a804c6.log")

# %% [markdown]
# # Hill Climbing
# - max_iter = 150_000

# %%
from northpole_packing.notebook import plot_hc
plot_hc("data/output_hc_15cf748b54fe4cadaba3cfa59ecc3b19.log", "num_trees=100")

# %% [markdown]
# # Tabu search
# - iterations=150_000
# - neighbors_per_iter=20
# - tabu_tenure=150

# %%
from northpole_packing.notebook import plot_ts
plot_ts("data/output_ts_bd27da79496e40bc92f2c06f0a48823b.log", "num_trees=100")
# Out:
# /Users/igor/PWR/aoin/src/northpole_packing/notebook.py:121: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   fig.legend()

# %%
from northpole_packing.notebook import compare_solutions
compare_solutions("data/output_saa_77b06160110c44d9a202bc3bd4a804c6.log", "data/output_hc_15cf748b54fe4cadaba3cfa59ecc3b19.log", "data/output_ts_bd27da79496e40bc92f2c06f0a48823b.log")

# %% [markdown]
# # num_trees=30

# %%
from northpole_packing.notebook import plot_hc, plot_sa, plot_ts, compare_solutions
plot_hc("results30/output_hc_dcdb3141e41a4d66accde8682f0c3075.log")
plot_sa("results30/output_saa_abd46c1add1345398552ab97e6d1e30b.log")
plot_ts("results30/output_ts_1f0d7384a9dc4eb2baca94349ac60dad.log")
compare_solutions("results30/output_saa_abd46c1add1345398552ab97e6d1e30b.log", "results30/output_hc_dcdb3141e41a4d66accde8682f0c3075.log", "results30/output_ts_1f0d7384a9dc4eb2baca94349ac60dad.log")
# Out:
# /Users/igor/PWR/aoin/src/northpole_packing/notebook.py:98: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   fig.legend()
# /Users/igor/PWR/aoin/src/northpole_packing/notebook.py:121: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   fig.legend()
